# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

# %%
img = cv2.imread('test2.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_resized = cv2.resize(img, (128,128))

# %%
pixel_values = np.reshape(img_resized, (-1, 3))
pixel_values.shape[1]
# Out:
# 3

# %%
plt.imshow(img_resized)
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
z_points = pixel_values[:,2]
x_points = pixel_values[:,0]
y_points = pixel_values[:,1]
ax.scatter3D(x_points, y_points, z_points, c=x_points, cmap='hsv')
plt.show()

# %%
def k_means():
    
    init_class = np.zeros(pixel_values.shape[0])
    print(init_class)
